# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style(style='darkgrid')

sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_style(style='whitegrid')

sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_style(style='white')

sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_style(style='dark')

sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_style(style='ticks')

sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Using Color Pallete

# %%
# sns.barplot(x='day',y='total_bill',data=tips,hue='sex',palette='deep')
# sns.barplot(x='day',y='total_bill',data=tips,hue='sex',palette='muted')
# sns.barplot(x='day',y='total_bill',data=tips,hue='sex',palette='pastel')
# sns.barplot(x='day',y='total_bill',data=tips,hue='sex',palette='bright')
# sns.barplot(x='day',y='total_bill',data=tips,hue='sex',palette='dark')
sns.barplot(x='day',y='total_bill',data=tips,hue='sex',palette='colorblind')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Creating Custom Color Pallete

# %%
custom_pallete = sns.color_palette(["#2ecc71", "#e74c3c", "#3498db", "#9b59b6"])

# %%
sns.set_palette(custom_pallete)

sns.barplot(x='day',y='total_bill',hue='sex',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Adjusting Figure Size

# %%
plt.figure(figsize=(10,12))

sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.relplot(x="total_bill", y="tip", data=tips, height=6, aspect=1.5)
